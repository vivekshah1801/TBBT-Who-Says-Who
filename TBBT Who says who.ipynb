# %% [markdown]
# # Searching for subtitles

# %% [markdown]
# Tried searching for subtitles with character names, but unable to find any reliable sources.
# Found https://bigbangtrans.wordpress.com/series-1-episode-1-pilot-episode/ with transcribe while googling.
#
# This blog has transcripts with somewhat sensible format which I think I can parse.
# Let's get all the transcripts.

# %% [markdown]
# # Getting transcripts

# %% [markdown]
# Found the sitemap: https://bigbangtrans.wordpress.com/sitemap.xml
#
# Let's parse this to get episode wise list.

# %%
import requests

sitemap_url = "https://bigbangtrans.wordpress.com/sitemap.xml"
res = requests.get(sitemap_url)
sitemap_data = res.text
print(sitemap_data[:100])
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <!-- generator="wordpress.com" -->
# <urlset xmlns:xsi="http://

# %%
# XML parsing is tedious. Convert to pythonic way via xmltodict
# !pip install xmltodict
# Out:
# Requirement already satisfied: xmltodict in ./venv/lib/python3.9/site-packages (0.14.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import xmltodict

# %%
sitemap_dict = xmltodict.parse(sitemap_data)
sitemap_dict.get('url')

# %%
urls = [x.get('loc') for x in sitemap_dict.get('urlset').get('url')]
urls = [x for x in urls if "series-" in x] # based on pattern in url
urls[:5]
# Out:
# ['https://bigbangtrans.wordpress.com/series-10-episode-24-the-long-distance-dissonance/',
#  'https://bigbangtrans.wordpress.com/series-10-episode-23-the-gyroscopic-collapse/',
#  'https://bigbangtrans.wordpress.com/series-10-episode-22-the-cognition-regeneration/',
#  'https://bigbangtrans.wordpress.com/series-10-episode-21-the-separation-agitation/',
#  'https://bigbangtrans.wordpress.com/series-10-episode-20-the-recollection-dissipation/']

# %%
# some swaggy OOP
from dataclasses import dataclass

@dataclass
class Transcript:
    season: int
    episode: int
    title: int
    link: str
    html_text: str = ""
    raw_text: str = ""

# %%
transcripts: list[Transcript] = []
for url in urls:
    scheme, _, site, path, _ = url.split("/")
    _, season, _, episode, title = path.split("-", maxsplit=4)
    transcript = Transcript(season=int(season), episode=int(episode), title=title, link=url)
    transcripts.append(transcript)
print(transcripts[:2])
# Out:
# [Transcript(season=10, episode=24, title='the-long-distance-dissonance', link='https://bigbangtrans.wordpress.com/series-10-episode-24-the-long-distance-dissonance/', html_text='', raw_text=''), Transcript(season=10, episode=23, title='the-gyroscopic-collapse', link='https://bigbangtrans.wordpress.com/series-10-episode-23-the-gyroscopic-collapse/', html_text='', raw_text='')]

# %%
# Download text
for transcript in transcripts:
    print(f"Downloading for {transcript.link}")
    res = requests.get(transcript.link)
    if res.status_code == 200:
        transcript.html_text = res.text
# Out:
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-24-the-long-distance-dissonance/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-23-the-gyroscopic-collapse/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-22-the-cognition-regeneration/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-21-the-separation-agitation/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-20-the-recollection-dissipation/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-19-the-collaboration-fluctuation/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-18-the-escape-hatch-identification/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-17-the-comic-con-conundrum/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-16-the-allowance-evaporation/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-15-the-locomotion-reverberation/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-14-the-emotion-detection-automation/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-13-the-romance-recalibration/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-12-the-holiday-summation/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-11-the-birthday-synchronicity/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-10-the-property-division-collision/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-09-the-geology-elevation/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-08-the-brain-bowl-incubation/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-07-the-veracity-elasticity/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-06-the-foetal-kick-catalyst/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-05-the-hot-tub-contamination/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-04-the-cohabitation-experimentation/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode-03-the-dependence-transcendence/
# Downloading for https://bigbangtrans.wordpress.com/series-10-episode

# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-3-episode-14-the-einstein-approximation/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-3-episode-13-the-bozeman-reaction/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-3-episode-12-the-psychic-vortex/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-3-episode-11-the-maternal-congruence/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-3-episode-10-the-gorilla-experiment/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-3-episode-09-the-vengeance-formulation/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-3-episode-08-the-adhesive-duck-deficiency/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-3-episode-07-the-guitarist-amplification/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-3-episode-06-the-cornhusker-vortex/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-3-episode-05-the-creepy-candy-coating-corollary/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-3-episode-04-the-pirate-solution/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-3-episode-03-the-gothowitz-deviation/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-3-episode-02-the-jiminy-conjecture/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-3-episode-01-the-electric-can-opener-fluctuation/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-23-the-monopolar-expedition/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-22-the-classified-materials-turbulence/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-21-the-vegas-renormalization/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-20-the-hofstadter-isotope/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-19-the-dead-hooker-juxtaposition/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-18-the-work-song-nanocluster/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-17-the-terminator-decoupling/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-16-the-cushion-saturation-3/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-15-the-maternal-capacitance/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-14-the-financial-permeability-2/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-13-the-friendship-algorithm/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-12-the-killer-robot-instability/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-11-the-bath-item-gift-hypothesis/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-11-the-vartabedian-conundrum/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-09-the-white-asparagus-triangulation/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-08-the-lizard-spock-expansion/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-07-the-panty-pinata-polarization/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-06-the-cooper-nowitzki-theorem-2/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-5-the-euclid-alternative/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-04-the-griffin-equivalency/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-03-the-barbarian-sublimation/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-02-the-codpiece-topology/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-2-episode-01-the-bad-fish-paradigm/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-17-the-tangerine-factor/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-16-the-peanut-reaction/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-15-the-porkchop-indeterminacy/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-14-the-nerdvana-annihilation/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-13-the-bat-jar-conjecture/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-12-the-jerusalem-duality/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-11-the-pancake-batter-anomaly/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-10-the-loobenfeld-decay/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-9-the-cooper-hofstadter-polarization/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-8-the-grasshopper-experiment/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-7-the-dumpling-paradox/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-6-the-middle-earth-paradigm/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-5-the-hamburger-postulate/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-4-the-luminous-fish-effect/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-3-the-fuzzy-boots-corollary/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-2-the-big-bran-hypothesis/
# Extracting text from HTML for https://bigbangtrans.wordpress.com/series-1-episode-1-pilot-episode/

# %% [markdown]
# # Parsing Dialogs
#
# Since now I have contents for the transcript, parse it in the dialogues.

# %%
len(transcripts)
# Out:
# 231

# %%
from typing import Optional


@dataclass
class Dialogue:
    speaker: str
    text: str
    transcript: Optional[Transcript]
    speaker_supporting_text: Optional[str] = ""

# %%
dialogues = []
for transcript in transcripts:
    lines = [x for x in transcript.raw_text.split("\n") if x]
    for line in lines:
        try:
            speaker, text = line.split(":", maxsplit=1)
            dialogue = Dialogue(speaker=speaker, text=text, transcript=transcript)
            dialogues.append(dialogue)
        except Exception as e:
            pass

# %%
len(dialogues)
# Out:
# 54652

# %% [markdown]
# # Filtering Scenes
# scenes are added in transcript with format `scene: Description`
# In out case it is parsed as dialogue with speaker = scene.

# %%
@dataclass
class Scene:
    description: str
    transcript: Optional[Transcript]

# %%
scenes = []
for dialogue in dialogues:
    if dialogue.speaker.lower() == 'scene':
        scene = Scene(description=dialogue.text, transcript=dialogue.transcript)
        scenes.append(scene)

# %%
dialogues = [x for x in dialogues if x.speaker.lower() != 'scene']

# %%
len(dialogues), len(scenes)
# Out:
# (51804, 2848)

# %% [markdown]
# # Check the speakers

# %%
speakers = list(set([x.speaker.lower() for x in dialogues]))
print(speakers[:10])
# Out:
# ['sheldon (now in a sparkly green suit with rhinestones)', 'katee', 'leonard, howard and raj (singing)', 'stuart (off)', 'stephen hawking', 'penny (knocking on door and entering)', 'susan (penny’s mother)', 'raj (reaching the other side)', 'leonard (voice off)', 'penny (entering, carrying a laptop)']

# %% [markdown]
# There are many speaker parsed as `speaker_name (blah-blah)`
# Let's add the information in bracket as speaker_supporting_text in dialogue

# %%
for i, dialogue in enumerate(dialogues):
    original_speaker = dialogue.speaker.lower().strip()
    if "(" in original_speaker or "(" in original_speaker:
        speaker, speaker_supporting_text = original_speaker.split("(", maxsplit=1)
        speaker = speaker.strip()
        speaker_supporting_text = speaker_supporting_text.replace(")","").replace("(","").strip()
    else:
        speaker = original_speaker
        speaker_supporting_text = ""
    dialogue.speaker = speaker
    dialogue.speaker_supporting_text = speaker_supporting_text

# %%
len(dialogues)
# Out:
# 51804

# %%
speakers = list(set([x.speaker for x in dialogues]))
speakers[:6]
# Out:
# ['katee',
#  'stephen hawking',
#  'mrs fowler',
#  'doctor',
#  'barber',
#  'first car thief']

# %%
from collections import defaultdict
dialogues_per_speaker = defaultdict(int)
for dialogue in dialogues:
    dialogues_per_speaker[dialogue.speaker] += 1

# %%
from collections import Counter
dialogues_per_speaker = Counter(dialogues_per_speaker)

# %%
dialogues_per_speaker
# Out:
# Counter({'sheldon': 11620,
#          'leonard': 9713,
#          'penny': 7677,
#          'howard': 5853,
#          'raj': 4669,
#          'amy': 3472,
#          'bernadette': 2684,
#          'stuart': 733,
#          'priya': 222,
#          'share this': 221,
#          'mrs cooper': 213,
#          'emily': 164,
#          'beverley': 162,
#          'mrs wolowitz': 136,
#          'zack': 135,
#          'arthur': 130,
#          'wil': 126,
#          'leslie': 113,
#          'kripke': 106,
#          'man': 105,
#          'bert': 95,
#          'barry': 79,
#          'lucy': 73,
#          'steph': 73,
#          'ramona': 71,
#          'all': 71,
#          'girl': 71,
#          'past sheldon': 66,
#          'past leonard': 64,
#          'dr koothrappali': 63,
#          'alex': 63,
#          'mary': 61,
#          'howard’s mother': 57,
#          'lesley': 53,
#          'dave': 52,
#          'gablehouser': 50,
#          'beverly': 48,
#          'mike': 48,
#          'dr hofstadter': 47,
#          'missy': 47,
#          'alfred': 46,
#          'claire': 43,
#          'elizabeth': 43,
#          'alicia': 43,
#          'wyatt': 42,
#          'sheldon-bot': 39,
#          'mr. rostenkowski': 38,
#          'mrs koothrappali': 38,
#          'together': 36,
#          'meemaw': 36,
#          'page': 36,
#          'isabella': 35,
#          'jimmy': 34,
#          'janine': 31,
#          'david': 31,
#          'dan': 30,
#          'dr koothrapalli': 29,
#          'dr lorvis': 29,
#          'mrs latham': 28,
#          'wil wheaton': 26,
#          'woman': 25,
#          'susan': 23,
#          'assistant': 23,
#          'kurt': 23,
#          'nurse': 20,
#          'policeman': 20,
#          'adam': 19,
#          'james': 19,
#          'past howard': 19,
#          'gablehauser': 19,
#          'lalita': 19,
#          'penny’s dad': 18,
#          'seibert': 18,
#          'dennis': 18,
#          'dr gallo': 17,
#          'colonel williams': 16,
#          'siri': 16,
#          'spock': 16,
#          'mrs davis': 16,
#          'dimitri': 16,
#          'alice': 16,
#          'voice': 15,
#          'waiter': 15,
#          'lakshmi': 15,
#          'summer': 15,
#          'christie': 15,
#          'randall': 14,
#          'mandy': 14,
#          'vet': 14,
#          'katee sackhoff': 14,
#          'hawking': 13,
#          'mr rostenkowski': 13,
#          'mrs hofstadter': 13,
#          'bethany': 13,
#          'toby': 13,
#          'caption': 12,
#          'josh': 12,
#          'security guard': 12,
#          'jesse': 12,
#          'joy': 12,
#          'past raj': 12,
#          'stephen hawking': 11,
#          'awkward guy': 11,
#          'ira': 11,
#          'prof crawley': 11,
#          'michaela': 11,
#          'kevin': 10,
#          'santa': 10,
#          'dmv lady': 10,
#          'rebecca': 9,
#          'theodore': 9,
#          'guy': 9,
#          'attorney': 9,
#          'doctor': 9,
#          'director': 9,
#          'hr woman': 9,
#          'barman': 8,
#          'col williams': 8,
#          'midwife': 8,
#          'maitre d’': 8,
#          'elon': 8,
#          'clerk': 8,
#          'waitress': 8,
#          'nathan fillion': 8,
#          'mike m': 8,
#          'ms jenson': 8,
#          'cosmonaut': 8,
#          'george takei': 8,
#          'martha': 8,
#          'everyone': 7,
#          'nerdy guy': 7,
#          'levar': 7,
#          'psychic': 7,
#          'answerphone': 7,
#          'cole': 7,
#          'receptionist': 7,
#          'glenn': 7,
#          'theatre staff': 7,
#          'judge': 7,
#          'katee': 7,
#          'cleaner': 6,
#          'mrs petrescu': 6,
#          'the flash': 6,
#          'air force officer': 6,
#          'official': 6,
#          'zombie': 6,
#          'prof sharpe': 6,
#          'rajj': 6,
#          'bermadette': 6,
#          'gps': 6,
#          'shopkeeper': 6,
#          'siebert': 6,
#          'todd': 6,
#          'venkatesh': 6,
#          'computer voice': 5,
#          'col. williams': 5,
#          'marty': 5,
#          'stephen': 5,
#          'soup kitchen manager': 5,
#          'mrs koothrapalli': 5,
#          'amelia': 5,
#          'woman on tv': 5,
#          'fat leonard': 5,
#          'leonard and howard': 5,
#          'teleplay': 5,
#          'story': 5,
#          'barber': 5,
#          'hot girl': 5,
#          'brent': 5,
#          'leonard and howard together': 5,
#          'actress': 5,
#          'steve wozniak': 5,
#          'stan lee': 5,
#          'prof laughlin': 5,
#          'eric': 5,
#          'both': 4,
#          'red-haired guy': 4,
#          'scanner': 4,
#          'sceme': 4,
#          'female voice': 4,
#          'second girl': 4,
#          'mike r': 4,
#          'man on tv': 4,
#          'rothman': 4,
#          'dale': 4,
#          'angela': 4,
#          'greene': 4,
#          'mrs fowler': 4,
#          'abby': 4,
#          'sarah': 4,
#          'tattooist': 4,
#          'third floor janitor': 4,
#          'strange old man': 3,
#          'jeff': 3,
#          'leslie winkle': 3,
#          'girls': 3,
#          'helium man': 3,
#          'howard and raj': 3,
#          'howard and bernadette': 3,
#          'first girl': 3,
#          'cooper': 3,
#          'jeannie': 3,
#          'hernandez': 3,
#          'mark harmon on tv': 3,
#          'bill': 3,
#          'mrs. rostenkowski': 3,
#          'man in suit': 3,
#          'dr schneider': 3,
#          'mission control': 3,
#          'mass': 3,
#          'second child': 3,
#          'dr tyson': 3,
#          'guard': 3,
#          'blonde girl': 3,
#          'phone rings. answering machine': 3,
#          'model': 3,
#          'warrior': 3,
#          'penny-warrior': 3,
#          'howard’s phone': 3,
#          'remote-control hawking': 2,
#          'daniel': 2,
#          'leonard and penny': 2,
#          'vanessa': 2,
#          'bespectacled man': 2,
#          'voice on tv': 2,
#          'levar burton': 2,
#          'woman’s voice': 2,
#          'all together': 2,
#          'store assistant': 2,
#          'mike massimino': 2,
#          'james earl jones': 2,
#          'various': 2,
#          'fat raj': 2,
#          'pizza guy': 2,
#          'everybody': 2,
#          'paramedic': 2,
#          '3.': 2,
#          'actor': 2,
#          'first car thief': 2,
#          'second car thief': 2,
#          'howie mandel': 2,
#          'man’s voice': 2,
#          'registrar': 2,
#          'phone': 2,
#          'barry’s siri': 2,
#          'child': 2,
#          'scene': 2,
#          'laura': 2,
#          'ghostly voice': 2,
#          'taxi driver': 2,
#          'on-screen sheldon': 2,
#          'radio': 2,
#          'dr millstone': 2,
#          'houston': 2,
#          'iss voice': 2,
#          'leonard’s mother': 2,
#          'employee': 2,
#          'raj & sheldon': 2,
#          'kathy': 2,
#          'cleaning lady 1': 2,
#          'tom': 2,
#          'owner': 2,
#          'dr gablehouser': 2,
#          'goldfarb': 2,
#          'student one': 2,
#          'student two': 2,
#          'ramona nowitzki': 1,
#          'col': 1,
#          'bar patrons': 1,
#          'halley': 1,
#          'following a “previously on” sequence': 1,
#          'mr spock cuckoo clock': 1,
#          'ellen': 1,
#          'howard’s cousin': 1,
#          'sheldon’s phone': 1,
#          'leonard and sheldon': 1,
#          'mary cooper': 1,
#          'alfred hofstadter': 1,
#          'adam west': 1,
#          'trent': 1,
#          'emly': 1,
#          'tall british dave': 1,
#          'kirk': 1,
#          'older woman': 1,
#          'headmaster': 1,
#          'tech support voice': 1,
#          'tech support guy': 1,
#          'audiitoner': 1,
#          'first alien': 1,
#          'second alien': 1,
#          'guy at door': 1,
#          'caller': 1,
#          'kevn': 1,
#          'ra': 1,
#          'baggage clerk': 1,
#          'woman in lab coat': 1,
#          'shedon': 1,
#          'nathan': 1,
#          'photographer': 1,
#          'leonard, howard and raj': 1,
#          'shldon': 1,
#          'man with flowers': 1,
#          'sehldon': 1,
#          'leoanard': 1,
#          'bill murray': 1,
#          'emily and penny': 1,
#          'stadium announcer': 1,
#          'man in crowd': 1,
#          'foreign nurse': 1,
#          'professor proton': 1,
#          'costume guy': 1,
#          'mrs': 1,
#          'announcement': 1,
#          'mike rostenkowski': 1,
#          'man in seat behind': 1,
#          'lady vet': 1,
#          'carrie fisher': 1,
#          'sweatpants': 1,
#          'voice on television': 1,
#          'second voice': 1,
#          'dead mrs wolowitz': 1,
#          'fat stuart': 1,
#          'fat leonard and raj': 1,
#          'ira flatow': 1,
#          'raj, bernadette and amy': 1,
#          'bill nye': 1,
#          'random voice': 1,
#          'boys': 1,
#          'howatd': 1,
#          '1. amy': 1,
#          '2.': 1,
#          '4. amy': 1,
#          '1.': 1,
#          '4. sheldon': 1,
#          '5.': 1,
#          'shelldon': 1,
#          'kid': 1,
#          'girl 2': 1,
#          'gretchen': 1,
#          'guys in passing car': 1,
#          'voice from outside': 1,
#          'girl dressed as a witch': 1,
#          'witch': 1,
#          'buzz': 1,
#          'various others': 1,
#          'roeger': 1,
#          'raj’s voice': 1,
#          'voice of spock': 1,
#          'sgeldon': 1,
#          'nasa guy': 1,
#          'dr massimino': 1,
#          'barry kripke': 1,
#          'sheldon’s voice': 1,
#          'minister': 1,
#          'speccy guy behind counter': 1,
#          'speccy guy': 1,
#          'brent spiner': 1,
#          '김수정 said this on\t\t\t\t\t\t\t\tnovember 24, 2011 at 2': 1,
#          'woman at table': 1,
#          'server': 1,
#          'elderly korean gentleman': 1,
#          'korean': 1,
#          'dr. brian greene': 1,
#          'voice inside': 1,
#          'huge man': 1,
#          'random man': 1,
#          'dr. seibert': 1,
#          'secne': 1,
#          'both together': 1,
#          'chorus of everyone in cafeteria': 1,
#          'very tall and powerfully built man': 1,
#          'tv announcer': 1,
#          'amy and bernadette together': 1,
#          'woman at door': 1,
#          'mechanical voice on sheldon’s phone': 1,
#          'rai': 1,
#          'man in penny’s apartment': 1,
#          'mrs gunderson': 1,
#          'man with a box': 1,
#          'large black transvestite': 1,
#          'transvestite': 1,
#          'joyce kim': 1,
#          'past penny': 1,
#          'television voice': 1,
#          'man on screen': 1,
#          'employment office assistant': 1,
#          'sheldon on laptop screen': 1,
#          'leonard and raj together': 1,
#          'all three': 1,
#          'the three guys': 1,
#          'guy in baseball hat': 1,
#          'second guy': 1,
#          'store clerk': 1,
#          'penny & sheldon together': 1,
#          'leonard & howard': 1,
#          'announcer': 1,
#          'george smoot': 1,
#          'woman in queue': 1,
#          'bookstore employee': 1,
#          'little girl': 1,
#          'voice from television': 1,
#          'voice from tv': 1,
#          'montage of scenes': 1,
#          'mr lefleur said this on\t\t\t\t\t\t\t\tfebruary 26, 2011 at 12': 1,
#          'cleaning lady 2': 1,
#          'charlie sheen': 1,
#          'raj and penny together': 1,
#          'penny- warrior': 1,
#          'leonard-warrior': 1,
#          'leonard-warrior’s head': 1,
#          'random woman': 1,
#          'random guy': 1,
#          'good looking man coming up stairs': 1,
#          'strange man': 1,
#          'christie and howard’s mother together': 1,
#          'nurse costume girl': 1,
#          'girl in hippie costume': 1,
#          'girl in butterfly costume': 1,
#          'butterfly girl': 1,
#          'male string quartettist': 1,
#          'female string quartettist': 1,
#          'doug': 1,
#          'class instructor': 1,
#          'leonard,sheldon and howard together': 1,
#          'voice from buzzer': 1,
#          'enormous man': 1})

# %% [markdown]
# # Cleaning and Fixing speaker names
#
# Based on the dialogues_per_speaker Counter instance, I have found that some speaker names are mistyped and misattributes.
#
# Creating a dictionary to fix them

# %%
speaker_rename_dict = {
    'barry': 'kripke', # Since we have both barry and kripke in the set, keeping only kripke to make it consistant
    'past sheldon': 'sheldon',
    'past leonard': 'leonard',
    'mary': 'mrs cooper',
    'howard’s mother': 'mrs wolowitz',
    'lesley': 'leslie',
    'beverly': 'beverley',
    'wil wheaton': 'wil',
    'penny’s dad': 'wyatt',
    'stephen hawking': 'hawking',
    # I am considering only these, others have only <20 instances
}

# %%
for dialogue in dialogues:
    dialogue.speaker = speaker_rename_dict.get(dialogue.speaker, dialogue.speaker)

# %% [markdown]
# # Big Question: How many times sheldon says the word `penny`

# %%
penny_count = 0
for dialogue in dialogues:
    if dialogue.speaker == 'sheldon':
        penny_count += dialogue.text.lower().count('penny')

# %%
penny_count
# Out:
# 543
